# %%
import nltk

# trees is a dict that maps from struct ids to bracketed trees
trees = {}
for line in open("../data/trees-for-nltk.tsv"):
    sid, struct = line.split("\t")
    sid = int(sid)
    trees[sid] = struct
    
nltk.Tree.fromstring(trees[833])
# Out:
# Tree('CP[ILLOC-DEC][+FIN]', ['Adv[+TOPIC]', Tree('Cbar[ILLOC-DEC][+FIN][SLASH-Adv]', [Tree('C[ILLOC-DEC][+FIN]', ['THAT[+NULL]']), Tree('IP[ILLOC-DEC][+FIN][SLASH-Adv]', ['S', Tree('Ibar[ILLOC-DEC][+FIN][SLASH-Adv]', [Tree('I[ILLOC-DEC][+FIN]', ['Aux[+FIN]']), Tree('VP[SLASH-Adv]', [Tree('Vbar[SLASH-Adv]', [Tree('V', ['Verb']), Tree('PP', ['P', 'O3'])])])])])])])
